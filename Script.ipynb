# %%
# For Python 2 / 3 compatibility
from __future__ import print_function
import numpy as np
import random

# %%
# TRAINING DATA
# Format: each row is an example.
# The last column is the label.
# The first columns is a feature.

training_data = [
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [-0.29,"Few"],
    [0.00,"All"],
    [0.29,"Most"],
    [0.29,"Lots of"],
    [-0.29,"Few"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"Most"],
    [0.29,"Majority"],
    [0.00,"All"],
    [1.00,"Half"],
    [0.29,"Almost all"],
    [0.00,"All"],
    [-0.29,"Some"],
    [1.00,"Evenly divided"],
    [0.80,"Half"],
    [0.50,"Almost equally mixed"],
    [0.50,"Predominantly"],
    [-0.50,"Few"],
    [0.50,"Mainly"],
    [0.50,"Most"],
    [0.50,"Most"],
    [-0.50,"Some"],
    [0.00,"Only"],
    [0.00,"All"],
    [0.00,"All"],
    [-0.29,"a pair of"],
    [0.29,"A lot of"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"Mostly"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.00,"Only"],
    [0.50,"Mostly"],
    [0.00,"All"],
    [0.50,"Most"],
    [0.50,"Lots of"],
    [-0.50,"Few"],
    [0.00,"All"],
    [0.50,"Most"],
    [-0.50,"Some"],
    [-0.29,"a pair of"],
    [0.00,"Only"],
    [0.00,"Only"],
    [0.29,"Lots of"],
    [-0.29,"A couple of"],
    [0.00,"All"],
    [0.00,"All"],
    [-0.29,"Some"],
    [-0.50,"Some"],
    [0.50,"A lot of"],
    [0.29,"Lots of"],
    [0.17,"Mostly"],
    [0.00,"All"],
    [0.17,"Vast majority"],
    [-0.13,"A"],
    [-0.29,"Some"],
    [0.13,"All except"],
    [-0.13,"A"],
    [0.13,"A lot of"],
    [0.13,"Nearly all"],
    [0.00,"All"],
    [-0.13,"A"],
    [0.13,"A lot of"],
    [-0.13,"A"],
    [0.17,"Mostly"],
    [0.29,"A lot of"],
    [0.17,"Most"],
    [1.00,"Equally divided"],
    [0.29,"Overwhelmingly"],
    [0.17,"Mostly"],
    [0.29,"Most"],
    [0.17,"Most"],
    [-0.29,"Few"],
    [0.50,"Mostly"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"Every"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"Several"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"A couple of"],
    [0.29,"All except"],
    [-0.29,"A couple of"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"Few"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Many more"],
    [0.00,"Only"],
    [0.00,"All"],
    [0.29,"A bit more"],
    [0.00,"All"],
    [0.29,"Most"],
    [0.00,"All"],
    [0.29,"Majority"],
    [-0.29,"A couple of"],
    [0.29,"Some"],
    [0.29,"Almost three quarters of"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Majority"],
    [0.00,"All"],
    [0.29,"Two thirds"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Mostly"],
    [0.00,"Only"],
    [0.00,"All"],
    [-0.29,"Only a couple of"],
    [0.00,"All"],
    [0.29,"A mix of"],
    [-0.29,"A mix of"],
    [0.00,"Only"],
    [0.29,"Majority"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Almost all"],
    [-0.29,"A couple of"],
    [0.29,"Many"],
    [0.00,"Every"],
    [0.00,"All"],
    [0.29,"Most except"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"a pair of"],
    [0.29,"Majority"],
    [0.80,"Mostly"],
    [-0.40,"Some"],
    [0.80,"Most"],
    [-0.29,"A couple of"],
    [-0.29,"A couple of"],
    [0.80,"Almost half"],
    [-0.29,"A couple of"],
    [-0.29,"A couple of"],
    [0.80,"Most"],
    [-0.29,"Few"],
    [-0.29,"Few"],
    [1.00,"An equal amount of"],
    [0.29,"More"],
    [-0.29,"Minority"],
    [0.29,"Mostly"],
    [-0.29,"A couple of"],
    [-0.29,"A couple of"],
    [0.29,"Mostly except"],
    [-0.29,"A couple of"],
    [-0.29,"A couple of"],
    [1.00,"An equal amount of"],
    [0.80,"Almost half"],
    [0.80,"Just over half"],
    [0.80,"Just over half"],
    [0.29,"Most"],
    [1.00,"Half"],
    [-0.29,"A couple of"],
    [0.80,"Some"],
    [0.80,"Lots of"],
    [-0.29,"A couple of"],
    [-0.29,"A couple of"],
    [0.80,"Most"],
    [0.80,"More"],
    [1.00,"Some"],
    [0.29,"Most except"],
    [0.29,"All except"],
    [0.29,"Several"],
    [0.40,"A mix of"],
    [-0.40,"A mix of"],
    [0.80,"Most"],
    [-0.29,"Some"],
    [-0.29,"Some"],
    [0.29,"Most"],
    [0.80,"Most"],
    [0.80,"Most except"],
    [-0.29,"a pair of"],
    [0.80,"More"],
    [0.50,"Mostly"],
    [-0.50,"Some"],
    [-0.50,"Some"],
    [-0.50,"Some"],
    [-0.29,"Few"],
    [0.80,"A mixture"],
    [0.50,"A mixture"],
    [0.80,"A mixture"],
    [0.50,"A mixture"],
    [0.80,"A mix of"],
    [0.50,"A mix of"],
    [0.50,"More"],
    [1.00,"Equally divided"],
    [0.50,"A bit more"],
    [0.50,"A mix of"],
    [0.50,"Predominantly"],
    [0.80,"Predominantly"],
    [-0.50,"One third"],
    [1.00,"An equal amount of"],
    [0.80,"Almost the same amount of"],
    [-0.50,"One third"],
    [0.50,"Two thirds"],
    [1.00,"Half"],
    [0.80,"Just over half"],
    [0.50,"Two thirds"],
    [0.80,"Slightly more"],
    [0.50,"Twice as many"],
    [0.67,"A mix of"],
    [0.33,"A mix of"],
    [0.80,"Some"],
    [-0.80,"Some"],
    [0.80,"Half"],
    [0.50,"Most except"],
    [-0.80,"Half"],
    [-0.50,"Some"],
    [-0.50,"Some"],
    [-0.29,"Small amount of"],
    [0.50,"Majority"],
    [0.80,"Majority"],
    [1.00,"Half"],
    [-0.33,"One third"],
    [0.00,"All"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"A couple of"],
    [0.00,"All"],
    [0.29,"Some"],
    [-0.29,"Some"],
    [0.29,"All except"],
    [0.00,"All"],
    [0.29,"Mostly"],
    [-0.29,"Only a few"],
    [0.00,"All"],
    [0.29,"Many more"],
    [0.00,"All"],
    [-0.29,"Less"],
    [-0.29,"Minority"],
    [0.00,"All"],
    [-0.29,"Some"],
    [0.29,"Mostly"],
    [-0.29,"Few"],
    [0.00,"All"],
    [0.29,"Majority"],
    [0.29,"Mostly"],
    [-0.29,"A couple of"],
    [0.00,"All"],
    [0.29,"Three quarters of"],
    [0.00,"All"],
    [0.29,"All except"],
    [-0.29,"Almost one third"],
    [0.29,"More"],
    [0.00,"Only"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"Only a couple of"],
    [0.00,"All"],
    [0.29,"Almost all"],
    [-0.29,"A couple of"],
    [0.00,"Exclusively"],
    [0.29,"Mostly"],
    [0.00,"All"],
    [0.29,"Majority"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"Most"],
    [0.29,"Most"],
    [-0.29,"a pair of"],
    [0.00,"All"],
    [0.50,"Double"],
    [0.00,"All"],
    [0.50,"A combination of"],
    [0.50,"Most"],
    [0.00,"Only"],
    [0.00,"All"],
    [0.50,"More"],
    [0.00,"All"],
    [-0.50,"One third"],
    [0.00,"All"],
    [0.50,"A bit more"],
    [0.00,"All"],
    [0.50,"A mix of"],
    [0.00,"Every"],
    [0.00,"All"],
    [-0.50,"One third"],
    [0.50,"Two thirds"],
    [0.00,"All"],
    [0.00,"Only"],
    [0.29,"Mostly"],
    [0.00,"Just"],
    [0.50,"More than half"],
    [0.00,"All"],
    [0.50,"Most"],
    [-0.50,"Few"],
    [0.00,"All"],
    [0.50,"More"],
    [-0.50,"Half"],
    [0.00,"All"],
    [0.50,"Most"],
    [-0.50,"Some"],
    [0.50,"Some"],
    [-0.50,"Some"],
    [0.50,"More"],
    [0.00,"Every"],
    [-0.50,"Some"],
    [0.00,"All"],
    [0.50,"Most"],
    [0.00,"All"],
    [0.50,"Most"],
    [0.00,"All"],
    [-0.50,"One third"],
    [0.29,"Mostly"],
    [-0.29,"A couple of"],
    [0.29,"Most"],
    [-0.29,"A couple of"],
    [0.29,"Majority"],
    [-0.29,"Few"],
    [0.29,"Mostly"],
    [-0.29,"Some"],
    [0.29,"Most"],
    [-0.29,"Some"],
    [0.00,"All"],
    [0.29,"A lot of"],
    [-0.29,"Only a few"],
    [-0.29,"Minority"],
    [0.29,"Majority"],
    [0.29,"Mostly"],
    [-0.29,"Few"],
    [0.29,"Lots of"],
    [-0.29,"A couple of"],
    [0.29,"All except"],
    [0.29,"Most"],
    [-0.29,"Only a few"],
    [0.29,"Majority"],
    [0.29,"Almost all except"],
    [0.29,"Lots of"],
    [-0.29,"A couple of"],
    [0.29,"Most"],
    [0.29,"Mostly"],
    [0.29,"Almost all"],
    [0.29,"All except"],
    [0.29,"Many more"],
    [0.29,"Majority"],
    [-0.29,"a pair of"],
    [0.29,"Most"],
    [0.50,"Majority"],
    [0.50,"Many"],
    [-0.50,"Only a couple of"],
    [0.50,"More"],
    [0.00,"All"],
    [0.50,"A mix of"],
    [0.50,"Mostly"],
    [-0.29,"Some"],
    [0.29,"Mostly"],
    [-0.50,"Few"],
    [0.50,"Lots of"],
    [-0.50,"One third"],
    [0.50,"Two thirds"],
    [0.50,"Two thirds"],
    [0.50,"Two thirds"],
    [0.50,"Majority"],
    [-0.50,"One third"],
    [-0.29,"Some"],
    [0.50,"Twice as many"],
    [-0.29,"a pair of"],
    [0.50,"Slightly Predominantly"],
    [0.00,"Only"],
    [0.50,"Mostly"],
    [-0.50,"Some"],
    [-0.50,"Less"],
    [0.50,"Many"],
    [0.00,"Every"],
    [0.50,"Most"],
    [-0.50,"Some"],
    [0.00,"All"],
    [0.50,"Two thirds"],
    [0.00,"All"],
    [0.11,"All but"],
    [0.11,"Most"],
    [0.11,"Almost all"],
    [0.11,"All except"],
    [0.00,"All"],
    [0.11,"All but"],
    [0.11,"All except"],
    [0.11,"All but"],
    [0.11,"Lots of"],
    [0.11,"All but"],
    [0.00,"All"],
    [0.11,"Almost all"],
    [0.11,"All except"],
    [0.11,"Almost all"],
    [0.00,"Only"],
    [0.00,"All"],
    [0.11,"Majority"],
    [0.11,"Almost all except"],
    [0.00,"All"],
    [0.11,"All except"],
    [0.11,"All except"],
    [0.11,"Almost all except"],
    [0.11,"All except"],
    [0.11,"All but"],
    [0.50,"Majority"],
    [-0.29,"A couple of"],
    [0.50,"Most"],
    [-0.29,"Few"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"One"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"A"],
    [-0.13,"A"],
    [0.50,"Big majority"],
    [0.29,"Primary"],
    [-0.29,"Few"],
    [0.50,"Majority"],
    [-0.13,"Not many"],
    [-0.13,"Only one"],
    [-0.14,"Only one"],
    [0.29,"More"],
    [0.29,"Mostly"],
    [0.29,"Mostly"],
    [0.50,"Mostly"],
    [0.50,"Most"],
    [0.29,"Almost three quarters of"],
    [0.29,"Almost three quarters of"],
    [0.50,"Two thirds"],
    [0.50,"Two thirds"],
    [-0.50,"One third"],
    [0.14,"All but"],
    [0.50,"Some"],
    [0.29,"Majority"],
    [0.17,"Majority"],
    [0.29,"Most"],
    [-0.29,"A couple of"],
    [-0.13,"Only one"],
    [-0.13,"Only one"],
    [0.50,"Mostly"],
    [-0.14,"Only one"],
    [0.29,"Almost all"],
    [0.50,"Many"],
    [0.50,"Majority"],
    [1.00,"An equal number of"],
    [0.50,"A lot of"],
    [-0.50,"A much lower amount of"],
    [0.29,"More"],
    [0.50,"Most"],
    [0.50,"Two thirds"],
    [0,"Only"],
    #Louk
    [0,"Only"],
    [0.00,"All"],
    [0,"A lot of"],
    [0,"Only"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0,"Only"],
    [0.33,"Mostly"],
    [0.33,"Most"],
    [0,"Only"],
    [0.33,"More"],
    [0.33,"Many more"],
    [0.33,"More"],
    [0.00,"All"],
    [-0.33,"About a third"],
    [0,"Only"],
    [0.33,"More"],
    [-0.25,"A small amount of"],
    [0.25,"Most"],
    [0,"Only"],
    [0.25,"Four times more"],
    [0.00,"All"],
    [0.25,"More"],
    [0,"Only"],
    [0.25,"More"],
    [0,"Only"],
    [0.25,"More"],
    [0.00,"All"],
    [0.25,"More"],
    [0.54,"Majority"],
    [1,"Almost the same amount of"],
    [0.54,"More"],
    [0.43,"More"],
    [0.67,"More"],
    [0.75,"More"],
    [1,"The same amount of"],
    [0.54,"More"],
    [0.75,"A couple more"],
    [0.43,"Slightly more"],
    [0.82,"Slightly more"],
    [0.54,"Majority"],
    [0.54,"Most"],
    [1,"The same amount of"],
    [0.86,"More"],
    [0.75,"The same amount of"],
    [0.86,"An equal amount of"],
    [0.75,"An equal amount of"],
    [0.54,"More"],
    [0.54,"More"],
    [0.82,"More"],
    [0.82,"More"],
    [0.54,"More"],
    [0.82,"Slightly more"],
    [0.54,"Slightly more"],
    [-0.11,"Minority"],
    [1,"An even amount of"],
    [0.18,"Most"],
    [-0.18,"Less"],
    [0.89,"More"],
    [0.18,"More"],
    [0.5,"More"],
    [0.13,"More"],
    [0.25,"More"],
    [0.82,"More"],
    [0.82,"More"],
    [0.82,"A mixture of"],
    [0.0,"All"],
    [0.5,"Some"],
    [0.67,"More"],
    [-0.67,"Less"],
    [0.5,"Most"],
    [0.75,"Most"],
    [1,"An equal amount of"],
    [0.67,"More"],
    [0.33,"More"],
    [0.67,"More"],
    [0.67,"A mixture of"],
    [0.67,"A mixture of"],
    [0.67,"Mostly"],
    [0.82,"More"],
    [1,"An equal number of"],
    [1,"An equal number of"],
    [0.71,"More"],
    [0.8,"More"],
    [0.67,"More"],
    [0.67,"More"],
    [0.82,"More"],
    [0.67,"A mixture of"],
    [0.67,"More"],
    [0.18,"Majority"],
    [-0.18,"Few"],
    [0.42,"Most"],
    [0.00,"All"],
    [0.6,"More"],
    [0.67,"More than half"],
    [0.18,"More"],
    [0.18,"Most"],
    [-0.67,"About a third"],
    [0.00,"All"],
    [0.82,"Almost the same amount of"],
    [0.82,"A bit more"],
    [0.82,"Most"],
    [0.83,"More"],
    [0.8,"More"],
    [0.82,"More"],
    [0.82,"Almost equally divided"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"Many"],
    [0.00,"All"],
    [0.00,"All"],
    [0.18,"Almost all"],
    [-0.18,"Some"],
    [0.00,"All"],
    [0.18,"Majority"],
    [0.18,"Mostly"],
    [0.00,"All"],
    [0.18,"Mostly"],
    [-0.18,"Some"],
    [0.18,"More"],
    [0.00,"All"],
    [0.18,"Majority"],
    [0.18,"Mainly"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"Every"],
    [0.00,"All"],
    [0.18,"More"],
    [0.00,"All"],
    [0.00,"All"],
    [0.18,"Most"],
    [1.00,"Half"],
    [1.00,"Half"],
    [0.54,"More"],
    [0.18,"Majority"],
    [1.00,"Most"],
    [0.18,"Some"],
    [0.86,"More"],
    [1.00,"Even"],
    [0.54,"More"],
    [0.54,"Mostly"],
    [-0.43,"Some"],
    [0.82,"Equally distributed"],
    [0.82,"More"],
    [0.18,"Majority"],
    [0.18,"Majority"],
    [0.18,"Mostly"],
    [0.18,"Most"],
    [0.18,"Mostly"],
    [0.18,"Mostly"],
    [-0.18,"Few"],
    [-0.18,"Few"],
    [0.18,"Most"],
    [0.00,"All"],
    [0.43,"Majority"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"Everything"],
    [0.00,"All"],
    [0.43,"More"],
    [0.43,"More"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.43,"Most"],
    [0.67,"More than half"],
    [0.67,"Mostly"],
    [0.67,"More"],
    [0.82,"Most"],
    [0.44,"More"],
    [0.67,"Roughly equivalent to"],
    [0.67,"Some"],
    [-0.67,"Some"],
    [0.82,"Slightly more"],
    [1.00,"Equal"],
    [0.82,"Mostly"],
    [0.82,"Some"],
    [-0.82,"Some"],
    [1.00,"An equal number"],
    [0.82,"More"],
    [0.82,"Some"],
    [1.00,"An even amount"],
    [0.82,"Slightly more"],
    [0.67,"More"],
    [0.80,"More"],
    [0.82,"More"],
    [0.00,"All"],
    [0.00,"All"],
    [0.82,"More"],
    [0.82,"Most"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.18,"Almost all"],
    [-0.18,"A couple of"],
    [0.18,"Most"],
    [-0.18,"Few"],
    [0.00,"Just"],
    [0.18,"Predominantly"],
    [-0.18,"Some"],
    [-0.18,"Few"],
    [0.85,"Mostly"],
    [-0.18,"Few"],
    [0.85,"Most"],
    [0.85,"Most"],
    [0.85,"Most"],
    [-0.18,"Some"],
    [0.18,"More"],
    [0.18,"Most"],
    [-0.18,"Some"],
    [0.18,"Mostly"],
    [-0.18,"Some"],
    [0.00,"All"],
    [0.18,"Majority"],
    [-0.18,"Less than a quarter of"],
    [0.00,"All"],
    [0.18,"Most"],
    [-0.18,"Some"],
    [0.00,"All"],
    [0.18,"Mostly"],
    [-0.18,"Slightly less"],
    [0.00,"All"],
    [-0.18,"Fewer"],
    [0.00,"All"],
    [0.18,"Majority"],
    [0.00,"All"],
    [0.18,"Mainly"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.18,"Most"],
    [-0.18,"Some"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.18,"Majority"],
    [0.00,"All"],
    [0.00,"All"],
    [0.75,"Mostly"],
    [1.00,"Some"],
    [0.54,"More"],
    [1.00,"Some"],
    [0.54,"Majority"],
    [1.00,"A mixture of"],
    [1.00,"Half"],
    [0.54,"Mainly"],
    [-0.54,"Some"],
    [1.00,"Some"],
    [-1.00,"Some"],
    [0.00,"All"],
    [1.00,"An equal amount of"],
    [1.00,"A mixture of"],
    [1.00,"Roughly the same amount of"],
    [0.67,"Roughly an equal amount of"],
    [1.00,"Roughly an equal amount of"],
    [1.00,"Equally distributed"],
    [0.67,"An even number"],
    [1.00,"A mixture of"],
    [0.82,"Mostly"],
    [0.54,"More"],
    [0.86,"A significant amount of"],
    [-0.18,"Few"],
    [0.82,"Some"],
    [0.82,"Some"],
    [0.82,"Almost evenly distributed"],
    [0.82,"A mixture of"],
    [0.82,"A mixture of"],
    [0.54,"Mainly"],
    [-0.18,"Few"],
    [0.82,"An equal number of"],
    [0.82,"Some"],
    [0.82,"Some"],
    [0.82,"Slightly more than"],
    [0.00,"A mixture of"],
    [0.00,"A mixture of"],
    [0.82,"Half"],
    [0.82,"Roughly the same amount of"],
    [0.00,"A mixture of"],
    [0.82,"About half"],
    [0.82,"One more"],
    [0.89,"Mostly"],
    [-0.11,"A couple of"],
    [-0.05,"Less than a couple of"],
    [0.18,"Most"],
    [-0.22,"Few"],
    [0.18,"Some"],
    [0.18,"Some"],
    [-0.18,"Some"],
    [-0.18,"Minority"],
    [0.13,"Mostly"],
    [-0.11,"Few"],
    [0.67,"Many"],
    [0.18,"Most"],
    [0.18,"Most"],
    [-0.18,"Some"],
    [0.18,"Almost all"],
    [0.18,"Most"],
    [0.18,"Most"],
    [-0.18,"Some"],
    [0.18,"Majority"],
    [-0.18,"Few"],
    [0.18,"Mostly"],
    [-0.18,"Less than a quarter"],
    [-0.18,"Few"],
    [0.18,"Mostly"],
    [0.00,"All"],
    [0.43,"Slightly more"],
    [0.00,"All"],
    [-0.43,"Few"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.43,"Slightly more"],
    [0.43,"A large number of"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.00,"All"],
    [0.43,"Most"],
    [0.43,"Roughly an equal amount of"],
    [0.00,"All"],
    [0.43,"About three quarters"],
    [0.00,"All"],
    [0.00,"All"],
    [0.71,"Mostly"],
    [0.33,"A small amount of"],
    [-0.44,"Few"],
    [0.67,"Some"],
    [0.67,"More"],
    [0.67,"Some"],
    [0.67,"More"],
    [0.82,"Slightly more"],
    [0.67,"More"],
    [0.67,"Most"],
    [-0.67,"Some"],
    [0.67,"Roughly the same amount of"],
    [0.67,"Slightly more than half"],
    [0.82,"Roughly an equal amount of"],
    [0.67,"More"],
    [0.67,"Some"],
    [-0.67,"Some"],
    [0.33,"Mostly"],
    [-0.82,"Fewer"],
    [0.80,"Mostly"],
    [-0.80,"Less"],
    [0.82,"Some"],
    [0.82,"A balance of"],
    [0.82,"Some"],
    [0.82,"About half"],
    [0.82,"Some"],
    [0.82,"More"],
    [0.82,"Almost evenly distributed"],
    [1.00,"Half"],
    [1.00,"Half"],
    [0.82,"Roughly the same amount of"],
    [0.82,"More than half"],
    [1.00,"Half"],
    [0.82,"A balance of"],
    [0.82,"Mostly"],
    [0.83,"Mostly"],
    [0.82,"Some"],
    [0.82,"About half"],
    [1.00,"Half"],
    [0.82,"Mostly"],
    [0.82,"Primarily"],
    [0.82,"Some"],
    [0.82,"Some"],
    [0.82,"Some"],
    [0.82,"Some"],
    [0.82,"About half"],
    [0.82,"Roughly the same amount of"],
    [0.82,"Roughly half"],
    [0.82,"More"],
    [0.01,"Almost all"],
    [0.01,"Almost all"],
    [0.03,"Almost all"],
    [0.05,"Almost all"],
    [0.01,"Almost all"],
    [0.06,"Almost all"],
    [0.02,"Almost all"],
]

# %%
# Column labels.
# These are used only to print the tree.
header = ["ratio", "label"]

# %%
def unique_vals(rows, col):
    #Find the unique values for a column in a dataset.
    return set([row[col] for row in rows])

# %%
#######
# Demo:
unique_vals(training_data, 0)
# unique_vals(training_data, 1)
#######
# Out:
# {-1.0,
#  -0.82,
#  -0.8,
#  -0.67,
#  -0.54,
#  -0.5,
#  -0.44,
#  -0.43,
#  -0.4,
#  -0.33,
#  -0.29,
#  -0.25,
#  -0.22,
#  -0.18,
#  -0.14,
#  -0.13,
#  -0.11,
#  -0.05,
#  0.0,
#  0.01,
#  0.02,
#  0.03,
#  0.05,
#  0.06,
#  0.11,
#  0.13,
#  0.14,
#  0.17,
#  0.18,
#  0.25,
#  0.29,
#  0.33,
#  0.4,
#  0.42,
#  0.43,
#  0.44,
#  0.5,
#  0.54,
#  0.6,
#  0.67,
#  0.71,
#  0.75,
#  0.8,
#  0.82,
#  0.83,
#  0.85,
#  0.86,
#  0.89,
#  1.0}

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
#######
# Occurrences of each quantifier in the training set:
class_counts(training_data)
# Out:
# {'A': 13,
#  'A balance of': 2,
#  'A bit more': 4,
#  'A combination of': 1,
#  'A couple more': 1,
#  'A couple of': 27,
#  'A large number of': 1,
#  'A lot of': 8,
#  'A mix of': 11,
#  'A mixture': 4,
#  'A mixture of': 12,
#  'A much lower amount of': 1,
#  'A significant amount of': 1,
#  'A small amount of': 2,
#  'About a third': 2,
#  'About half': 4,
#  'About three quarters': 1,
#  'All': 202,
#  'All but': 6,
#  'All except': 13,
#  'Almost all': 18,
#  'Almost all except': 3,
#  'Almost equally divided': 1,
#  'Almost equally mixed': 1,
#  'Almost evenly distributed': 2,
#  'Almost half': 2,
#  'Almost one third': 1,
#  'Almost the same amount of': 3,
#  'Almost three quarters of': 3,
#  'An equal amount of': 7,
#  'An equal number': 1,
#  'An equal number of': 4,
#  'An even amount': 1,
#  'An even amount of': 1,
#  'An even number': 1,
#  'Big majority': 1,
#  'Double': 1,
#  'Equal': 1,
#  'Equally distributed': 2,
#  'Equally divided': 2,
#  'Even': 1,
# ...

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %%
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            header[self.column], condition, str(self.value))

# %%
def partition(rows, question):
    #Partitions a dataset. For each row in the dataset, check if it matches the question. If so, add it to 'true rows', otherwise, add it to 'false rows'.
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
def gini(rows):
    # Calculate the Gini Impurity for a list of rows.
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def info_gain(left, right, current_uncertainty):
    # Information Gain.
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
def find_best_split(rows):
    # Find the best question to ask by iterating over every feature / value and calculating the information gain.
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

# %%
class Leaf:
    # A Leaf node classifies data. 
    # This holds a dictionary of class (e.g., "Apple") -> number of times it appears in the rows from the training data that reach this leaf.
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    # A Decision Node asks a question.
    # This holds a reference to the question, and to the two child nodes.
    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    # Builds the tree.

    # Rules of recursion: 
    # 1) Believe that it works. 
    # 2) Start by checking for the base case (no further information gain). 
    # 3) Prepare for giant stack traces.

    # Try partitioning the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question = find_best_split(rows)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # dependingo on the answer.
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    # Tree printing function.

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print (spacing + "Predict", node.predictions)
        return

    # Print the question at this node
    print (spacing + str(node.question))

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print (spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
my_tree = build_tree(training_data)
print_tree(my_tree)

def classify(row, node):
    # According to the rules of recursion above.

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):        
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)
# Out:
# Is ratio >= 0.01?
# --> True:
#   Is ratio >= 0.54?
#   --> True:
#     Is ratio >= 1.0?
#     --> True:
#       Predict {'Half': 11, 'Evenly divided': 1, 'Equally divided': 2, 'An equal amount of': 5, 'Some': 4, 'An equal number of': 3, 'Almost the same amount of': 1, 'The same amount of': 2, 'An even amount of': 1, 'Most': 1, 'Even': 1, 'Equal': 1, 'An equal number': 1, 'An even amount': 1, 'A mixture of': 3, 'Roughly the same amount of': 1, 'Roughly an equal amount of': 1, 'Equally distributed': 1}
#     --> False:
#       Is ratio >= 0.75?
#       --> True:
#         Is ratio >= 0.82?
#         --> True:
#           Is ratio >= 0.83?
#           --> True:
#             Is ratio >= 0.86?
#             --> True:
#               Is ratio >= 0.89?
#               --> True:
#                 Predict {'More': 1, 'Mostly': 1}
#               --> False:
#                 Predict {'More': 2, 'An equal amount of': 1, 'A significant amount of': 1}
#             --> False:
# ...

# %%
def print_leaf(counts):
    probabsLoc = []
    arrayLoc = []
    arrayLoc = [k for k, v in counts.items()]
    # A nicer way to print the predictions at a leaf.
    total = sum(counts.values()) * 1.0
    probs = {}
    for i in range(0,len(counts)):
        probabsLoc.append(float([x for x in counts.values()][i]) / total)
    probabs = probabsLoc
    array = arrayLoc
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    
    return probs, probabs, array

# %%
# UTILS

from itertools import combinations
import itertools

# Function to compute how many compositions exist where 4 numbers sum up to n
# E.g. the number of compositions possible with a total of 9 and 4 numbers is 220 (including permutations of course)
def compositions(num, width):
    m = num + width - 1
    last = (m,)
    first = (-1,)
    for t in combinations(range(m), width - 1):
        yield [v - u - 1 for u, v in zip(first + t, t + last)]

# =========================================================================================================        
        
# Function to generate nrSamples of n objects  
def genSamples(n, nrSamples):
    # test
    i = 0
    for t in compositions(n, 4):
        i = i + 1
    comp = list(compositions(n,4))
    comp = sorted(comp)
    rand_items = random.sample(comp, nrSamples)
    return rand_items

# Function to prevent errors when one of the numbers of the division is a 0
def divideByZero(arg1, arg2):
    if(arg1 == 0 or arg2 == 0):
        return 0.00
    else:
        return round(arg1/arg2, 2)

# =========================================================================================================
    
# Function to compute the opposite value when a quantifier like 'more than' is used (e.g. 'there are more red objects than blue objects')    
def getOppositeValue(value):
    if(value == 'red'):
        value == 'red objects'
        opposite = 'blue objects'
    elif(value == 'blue'):
        value == 'blue objects'
        opposite = 'red objects'
    elif(value == 'squares'):
        opposite = 'circles'
    elif(value == 'circles'):
        opposite = 'squares'
    else:
        opposite = 'other objects'
    return value, opposite

# =========================================================================================================

# Function that converts the numbers into strings (e.g. 1 becomes 'One')
def convertToWords(num): 
    ones = ['', 'One', 'Two', 'Three', 'Four', 'Five', 'Six']
    if(int(num) < 7):
        word = ones[int(num)]
        return word
    else:
        return 'few'

# =========================================================================================================

# Function used to calculate the correct number of remaining objects when using the quantifier 'all but n' or 'most except for n'
def calculateRemainder(value, secVal):
    if(secVal == 'combination'):
        if(value == 'red squares'):
            remainder = n - RS
        elif(value == 'blue squares'):
            remainder = n - BS
        elif(value == 'red circles'):
            remainder = n - RC
        else:
            remainder = n - BC
    elif(secVal != 'none'):
        if(value == 'red'):
            if(secVal == 'squares'):
                remainder = BS
            else:
                remainder = BC
        elif(value == 'blue'):
            if(secVal == 'squares'):
                remainder = RS
            else:
                remainder = RC
        elif(value == 'squares'):
            if(secVal == 'red'):
                remainder = RS
            else:
                remainder = BS
        else:
            if(secVal == 'red'):
                remainder = RC
            else:
                remainder = BC        
    else:
        if(value == 'red'):
            remainder = B
        elif(value == 'blue'):
            remainder = R
        elif(value == 'circles'):
            remainder = S
        elif(value == 'squares'):
            remainder = C
        else:
            remainder = 0
    return convertToWords(remainder)

# =========================================================================================================

def countHowMany(value):
    if(value == 'red'):
        return R
    elif(value == 'blue'):
        return B
    elif(value == 'squares'):
        return S
    else:
        return C

# =========================================================================================================

def proceedWithColour():
    if(doneColour == 'red'):
        if(R>B):
            if(finalRatioColour[0] >= 0):
                finalRatioColour[0] = -finalRatioColour[0]
            generateQuant(finalRatioColour,True)
    else:
        if(B>R):
            if(finalRatioColour[0] >= 0):
                finalRatioColour[0] = -finalRatioColour[0]
            generateQuant(finalRatioColour,True)

# =========================================================================================================
            
def proceedWithShape():
    if(doneShape == 'squares'):
        if(S>C):
            if(finalRatioShape[0] >= 0):
                finalRatioShape[0] = -finalRatioShape[0]
            generateQuant(finalRatioShape,False)
    else:
        if(C>S):
            if(finalRatioShape[0] >= 0):
                finalRatioShape[0] = -finalRatioShape[0]
            generateQuant(finalRatioShape,False)

# =========================================================================================================            
            
def computeRatios(arg1,arg2):
    ratio = [arg1,arg2]
    
    ratio1 = round(divideByZero(arg1,arg2), 2)
    ratio2 = round(divideByZero(arg2,arg1), 2)
    finalRatio = min(ratio1, ratio2)

    # Randomise the choice of adding the minus before the final ratio IF ratio is different from 0 or 1
    # We do this to make sure that we don't always consider the majority but also the minority of objects
    if(finalRatio == 1.0 or finalRatio == 0.0):
        finalRatio = [finalRatio, ""]
    else:
        finalRatio = [np.random.choice([-finalRatio,finalRatio], 1, p=[0.2, 0.8])[0],""]
    return finalRatio

# %%
# TEMPLATE GENERATION

# Function to generate templates. It is very long but takes into account probably every quantifier we found in our experimental data by grouping them
def templateGenerator(quantifier, value, inner):
    quantifier = quantifier.lower()
    special = ['all', 'many', 'most', 'a lot of', 'lots of', 'few']

    # Special case: 'All, Many, Most, A lot of, Lots of, Few,' ==> template: Q + 'objects are' + '...'
    if(quantifier in special):
        sentence = ('%s objects are %s' % (quantifier, value))
        return sentence
    
    # Handle case 'most but n' or 'all except for n' ==> template: Q + 'objects but/except for' + n + 'are' + '...'
    elif(' but' in quantifier or 'except' in quantifier):
        otherVar = inner
        remainder = calculateRemainder(value, otherVar)
        if('but' in quantifier):
            newQuantifier = quantifier.split(' but')[0]
            conj = 'but'
        else:
            newQuantifier = quantifier.split(' except')[0]
            conj = 'except for'
        sentence = ('%s objects %s %s are %s' % (newQuantifier, conj, remainder, value))
        sentence.replace("  ", " ")
        return sentence
    
    # Handle 'a'
    elif(quantifier == 'a' or quantifier.endswith(' one')):
        if(value == 'red' or value == 'blue'):
            if(countHowMany(value) == 1):
                value = value + ' object'
                sentence = ('There is %s %s' % (quantifier, value))
            else:
                value = value + ' objects'
                quantifier = 'few'
                sentence = ('There are %s %s' % (quantifier, value))
        else:
            if(countHowMany(value) == 1):
                value = value[:-1]
                sentence = ('There is %s %s' % (quantifier, value))
            else:
                quantigier = 'few'
                sentence = ('There are %s %s' % (quantifier, value))
        return sentence
    
    # Majority, minority ==> 'The' + Q + 'of objects is' + '...'
    elif('majority' in quantifier or 'minority' in quantifier):
        sentence = ('The %s of objects is %s' % (quantifier, value))
        return sentence
    
    # Handle 'every'
    elif('every' in quantifier):
        if(value == 'red' or value == 'blue'):
            bit = 'is %s' % value
        else:
            bit = 'is a %s' % value
        sentence = ('%s object %s' % (quantifier, bit))
    
    # Handle fractions
    elif('half' in quantifier or 'third' in quantifier or 'fourth' in quantifier or 'fifth' in quantifier):
        sentence = ('%s of the objects are %s' % (quantifier, value))
        return sentence
    
    # Handle quantifiers that divide the objects in two
    elif('divided' in quantifier or 'split' in quantifier or 'mixed' in quantifier):
        value, opposite = getOppositeValue(value)
        sentence = ('The objects are %s between %s and %s' % (quantifier, value, opposite))
        return sentence
    
    # Handle cases such as 'twice as many' or 'three times as many'
    elif('twice' in quantifier or 'times' in quantifier):
        value, opposite = getOppositeValue(value)
        sentence = ('There are %s %s as %s' % (quantifier, value, opposite))
        return sentence
    
    # Adverbs = ending in "ly" ==> templates: 
    # 1) 'There are' + Q + '...' 
    # 2) 'The objects are' + Q + '...'
    elif(quantifier.endswith('ly')):
        tempChosen = np.random.choice([1,2], 1, p=[0.5, 0.5])[0]
        if(tempChosen == 1):
            sentence = ('The objects are %s %s' % (quantifier, value))
            return sentence
        else:
            if(value == 'red' or value == 'blue'):
                value = value + ' objects'
            else:
                value = value
            sentence = ('There are %s %s' % (quantifier, value))
            return sentence
    
    # Handle cases such as 'equal/same amount/number of'
    elif('equal' in quantifier or 'same' in quantifier or 'even' in quantifier or 'mix' in quantifier or 'balance' in quantifier):
        value, opposite = getOppositeValue(value)
        if(opposite == 'other objects'):
            opposite = 'the rest of the objects'
        sentence = ('There is %s %s and %s' % (quantifier, value, opposite))
        return sentence
    
    # Handle cases such as 'A couple/pair of' etc. and in general quantifiers that finish with 'of' but that are not represented in any of the earlier conditions
    elif(quantifier.endswith('of')):
        sentence = ('%s the objects are %s' % (quantifier, value))
        return sentence
    
    # Comparisons
    elif('more' in quantifier or 'less' in quantifier):
        value, opposite = getOppositeValue(value)
        sentence = ('There are %s %s than %s' % (quantifier, value, opposite))
        return sentence

    # General case: 'There are' + Q + '...'
    else:
        newValue = ' objects'
        if(value == 'squares' or value == 'circles' or inner == 'combination'):
            newValue = ''
        sentence = ('There are %s %s%s' % (quantifier, value, newValue))
        return sentence

# %%
# QUANTIFIER GENERATION

# Function to generate a quantifier for a combination of properties such as red squares, blue circles, etc.
def combinationQuant(ratio):
    lista, probabs, array = print_leaf(classify(ratio, my_tree))
    #print ("Ratio: %s" % ratio[-2])
    col = max(R,B)
    if(col == R):
        col = 'red'
    else:
        col = 'blue'
    
    shape = max(S,C)
    if(shape == S):
        shape = 'squares'
    else:
        shape = 'circles'

    comb = col + ' ' + shape 
    sent = ('%s.' % templateGenerator(np.random.choice(array,1,p=probabs)[0], comb, 'combination'))
    print((sent.lower()).capitalize())
    return col, shape    
    
# =========================================================================================================
    
# Function to generate quantifiers that prints the final sentence
def generateQuant(ratio,colour):
    lista, probabs, array = print_leaf(classify(ratio, my_tree))
    #print ("Ratio: %s" % ratio[-2])
    if(ratio[-2] == 1.0):
        if(colour):
            value = 'blue'
        else:
            value = 'circles'
    elif(ratio[-2] == 0.00):
        if(colour):
            if(max(R,B) == B):
                value = 'blue'
            else:
                value = 'red'
        else:
            if(max(S,C) == S):
                value = 'squares'
            else:
                value = 'circles'
    elif(ratio[-2] > 0):
        if(colour):
            if(B>R):
                value = 'blue'
            else:
                value = 'red'
        else:
            if(C>S):
                value = 'circles'
            else:
                value = 'squares'    
    else:
        if(colour):
            if(B>R):
                value = 'red'
            else:
                value = 'blue'
        else:
            if(C>S):
                value = 'squares'
            else:
                value = 'circles'
    sent = ('%s' % templateGenerator(np.random.choice(array,1,p=probabs)[0], value, 'none'))
    
    if(colour):
        if(sent.startswith('There is a ') or sent.startswith('There is only')):
            inner = checkInnerShape(value, True)
        else:
            inner = checkInnerShape(value, False)
    else:
        if(sent.startswith('There is a ') or sent.startswith('There is only')):
            inner = checkInnerColour(value, True)
        else:
            inner = checkInnerColour(value, False)
    if(sent.startswith('There is a ') or sent.startswith('There is only')):
        complete = (sent.lower().capitalize()) + (inner.lower()) + '.'
    else:
        complete = (sent.lower().capitalize()) + '. ' + (inner.lower().capitalize()) + '.'
    print(complete)
    
# =========================================================================================================    
    
# Function to find a quantifier for a specific colour (e.g. how many squares within the red objects)
def checkInnerShape(col, single):
    if(col == 'red'):
        col = 'red objects'
        innerRatio = [min(divideByZero(RS,RC), divideByZero(RC,RS)), ""]
        if(innerRatio[0] == 0):
            if(RC == 0):
                shape = 'squares'
            else:
                shape = 'circles'
        else:
            if(innerRatio[0] == divideByZero(RS,RC)):
                shape = 'circles'
            else:
                shape = 'squares'
    else:
        col = 'blue objects'
        innerRatio = [min(divideByZero(BS,BC), divideByZero(BC,BS)), ""]
        if(innerRatio[0] == 0):
            if(BC == 0):
                shape = 'squares'
            else:
                shape = 'circles'
        else:
            if(innerRatio[0] == divideByZero(BS,BC)):
                shape = 'circles'
            else:
                shape = 'squares'
    second_list, probs, arr = print_leaf(classify(innerRatio, my_tree))
    if(single):
        return (" and it is a %s" % shape[:-1])
    else:
        return ("%s the %s, %s" % ((np.random.choice(['Within', 'Among'], 1, p=[0.5,0.5])[0]), col, templateGenerator(np.random.choice(arr, 1, p=probs)[0], shape, col)))
    
# =========================================================================================================
    
# Function to find a quantifier for a specific shape (e.g. how many red objects within the squares)
def checkInnerColour(shape, single):
    if(shape == 'squares'):
        innerRatio = [min(divideByZero(BS,RS), divideByZero(RS,BS)), ""]
        if(innerRatio[0] == 0):
            if(BS == 0):
                col = 'red'
            else:
                col = 'blue'
        else:
            if(innerRatio[0] == divideByZero(BS,RS)):
                col = 'red'
            else:
                col = 'blue'
    else:
        innerRatio = [min(divideByZero(BC,RC), divideByZero(RC,BC)), ""]
        if(innerRatio[0] == 0):
            if(BC == 0):
                col = 'red'
            else:
                col = 'blue'
        else:
            if(innerRatio[0] == divideByZero(BC,RC)):
                col = 'red'
            else:
                col = 'blue'
    second_list, probs, arr = print_leaf(classify(innerRatio, my_tree))
    if(single):
        return (" and it is %s" % col)
    else:
        return ("%s the %s, %s" % ((np.random.choice(['Within', 'Among'], 1, p=[0.5,0.5])[0]), shape, templateGenerator(np.random.choice(arr, 1, p=probs)[0], col, shape)))

# %% [markdown]
# # input is inserted in this way: [RS, BS, BC, RC]
#
# # Number of objects n
# n = 35
#
# # Number of samples to describe
# s = 5
#
# # Generate s samples with n objects
# testData = genSamples(n,s)
#
# # Produce a description for each of the samples
# for scenario in testData:
#     print('[RS, BS, BC, RC]')
#     print(scenario)
#     input = scenario
#
#     RS = input[0]
#     BS = input[1]
#     BC = input[2]
#     RC = input[3]
#
#     R = RS + RC
#     B = BS + BC
#     S = RS + BS
#     C = RC + BC
#
#     # =============================================================================================
#
#     # Compute ratios for colour
#     finalRatioColour = computeRatios(R,B)
#
#     # Compute ratios for shape
#     finalRatioShape = computeRatios(S,C)
#
#     # =============================================================================================
#
#     doneShape = ''
#     doneColour = ''
#
#     # Check if any of the combinations is predominant in the scenario (i.e. it occurs more than n/2 times)
#     for elem in input:
#         if(elem > n/2):
#             doneColour, doneShape = combinationQuant([round((n-elem)/elem, 2), ""])
#             # Call only one between shapeQuant or colourQuant after doing combinationQuant to avoid redundancies
#             if(elem < n):
#                 rand = np.random.choice([1,2], 1, p=[0.5,0.5])[0]
#                 if(rand == 1):
#                     # Make sure that the objects can be differentiated by colour, otherwise proceed by shape
#                     if(finalRatioColour[0] > 0 or finalRatioColour[0] < 0):
#                         proceedWithColour()
#                     else:
#                         proceedWithShape()
#                 else:
#                     # Make sure that the objects can be differentiated by shape, otherwise proceed by colour
#                     if(finalRatioShape[0] > 0 or finalRatioShape[0] < 0):
#                         proceedWithShape()
#                     else:
#                         proceedWithColour()
#
#
#     # If none of the combinations is predominant in the scenario, then check if a property is shared by all objects (i.e. all objects are red or all objects are squares etc.)
#     # If so, then only do shapeQuant or colourQuant with respect to that property
#     if(not doneColour or not doneShape):
#         if(finalRatioColour[0] == 0.0):
#             generateQuant(finalRatioColour,True)
#         elif(finalRatioShape[0] == 0.0):
#             generateQuant(finalRatioShape,False)
#         else:
#             generateQuant(finalRatioColour,True)
#             generateQuant(finalRatioShape,False)
#
#     print('------------------------------------------------------------------------------------------------------')
#     print('------------------------------------------------------------------------------------------------------\n\n')
